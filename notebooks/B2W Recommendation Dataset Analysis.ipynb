# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

module_path
# Out:
# '/home/lamagui/Workspace/bertology'

# %%
import pandas as pd
from src.data import b2w
from src.data import reporter

# %%
# reads the dataset
dataset = b2w.get_dataframe(usecols=['review_text', 'recommend_to_a_friend'])
print(dataset.shape)
dataset.head()
# Out:
# (132373, 2)
#   recommend_to_a_friend                                        review_text
# 0                   Yes  Estou contente com a compra entrega rápida o ú...
# 1                   Yes  Por apenas R$1994.20,eu consegui comprar esse ...
# 2                   Yes  SUPERA EM AGILIDADE E PRATICIDADE OUTRAS PANEL...
# 3                   Yes  MEU FILHO AMOU! PARECE DE VERDADE COM TANTOS D...
# 4                   Yes  A entrega foi no prazo, as americanas estão de...

# %%
# dataset analysis
reporter.corpus_analysis(
    dataset[['review_text']],
    cdist_kw=dict(
        figsize=(15,4),
        x_values=dict(
            review_text=range(0, 151, 5)
        )
    )
)
# Out:
# # Sentence Size
# ## review_text
# # Cumulative Sentence Size
# ## review_text

# %% [markdown]
# # recommend_to_a_friend

# %%
# distribuição do target
dataset.recommend_to_a_friend.value_counts()
# Out:
# Yes    96368
# No     35987
# Name: recommend_to_a_friend, dtype: int64

# %%
# distribuição do target
dataset.recommend_to_a_friend.value_counts(normalize=True)
# Out:
# Yes    0.728102
# No     0.271898
# Name: recommend_to_a_friend, dtype: float64

# %%
# Valores Nulos
dataset.recommend_to_a_friend.isna().value_counts()
# Out:
# False    132355
# True         18
# Name: recommend_to_a_friend, dtype: int64
